# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"C:/Users/M.Tahir/OneDrive/Belgeler/GitHub/covid_19_data_tr.csv")

# %%
data.describe()
# Out:
#        Province/State      Confirmed       Deaths      Recovered
# count             0.0     113.000000   113.000000     113.000000
# mean              NaN  108940.707965  2880.415929   73079.230088
# std               NaN   68862.565123  1901.552034   64726.893867
# min               NaN       1.000000     0.000000       0.000000
# 25%               NaN   38226.000000   812.000000    1846.000000
# 50%               NaN  131744.000000  3584.000000   78202.000000
# 75%               NaN  166422.000000  4609.000000  130852.000000
# max               NaN  201098.000000  5150.000000  175422.000000

# %%
data.head(30)
# Out:
#     Province/State Country/Region  Confirmed  Deaths  Recovered Last_Update
# 0              NaN         Turkey        1.0     0.0        0.0   3/11/2020
# 1              NaN         Turkey        1.0     0.0        0.0   3/12/2020
# 2              NaN         Turkey        5.0     0.0        0.0   3/13/2020
# 3              NaN         Turkey        5.0     0.0        0.0   3/14/2020
# 4              NaN         Turkey       18.0     0.0        0.0   3/15/2020
# 5              NaN         Turkey       47.0     0.0        0.0   3/16/2020
# 6              NaN         Turkey       98.0     1.0        0.0   3/17/2020
# 7              NaN         Turkey      191.0     2.0        0.0   3/18/2020
# 8              NaN         Turkey      359.0     4.0        0.0   3/19/2020
# 9              NaN         Turkey      670.0     9.0        0.0   3/20/2020
# 10             NaN         Turkey      947.0    21.0        0.0   3/21/2020
# ...

# %%
data.tail(30)
# Out:
#      Province/State Country/Region  Confirmed  Deaths  Recovered Last_Update
# 89              NaN         Turkey   171121.0  4711.0   141380.0    6/8/2020
# 90              NaN         Turkey   172114.0  4729.0   144598.0    6/9/2020
# 91              NaN         Turkey   173036.0  4746.0   146839.0   6/10/2020
# 92              NaN         Turkey   174023.0  4763.0   147860.0   6/11/2020
# 93              NaN         Turkey   175218.0  4778.0   149102.0   6/12/2020
# 94              NaN         Turkey   176677.0  4792.0   150087.0   6/13/2020
# 95              NaN         Turkey   178239.0  4807.0   151417.0   6/14/2020
# 96              NaN         Turkey   179831.0  4825.0   152364.0   6/15/2020
# 97              NaN         Turkey   181298.0  4842.0   153379.0   6/16/2020
# 98              NaN         Turkey   182727.0  4861.0   154640.0   6/17/2020
# 99              NaN         Turkey   184031.0  4882.0   156022.0   6/18/2020
# ...

# %%
data.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Confirmed', 'Deaths', 'Recovered',
#        'Last_Update'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Province/State    119
# Country/Region      6
# Confirmed           6
# Deaths              6
# Recovered           6
# Last_Update         6
# dtype: int64

# %% [markdown]
# # değişkenlerin dağılım grafikleri ile ilişkilendirilmesi

# %%
sns.relplot(x="Confirmed" , y="Recovered",hue="Deaths",data=data)

# %%
sns.pairplot(data)

# %%
data.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Confirmed', 'Deaths', 'Recovered',
#        'Last_Update'],
#       dtype='object')

# %%
sns.relplot(x="Recovered",y="Deaths",kind="line",data=data)

# %%
sns.catplot(x="Recovered",y="Confirmed",data=data)
